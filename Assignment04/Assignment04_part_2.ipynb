# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitjadhav10/data690_ajit/blob/main/Assignment04/Assignment04_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# - 1. Use Pandas to read the file census_costs.txt file

# %%
df = pd.read_csv("/content/census_cost.txt", sep="\t")
df.head()
# Out:
#   Census Year Total Population Census Cost Average Cost Per Person
# 0        1790        3,929,214     $44,377              1.13 cents
# 1        1800        5,308,483     $66,109              1.24 cents
# 2        1810        7,239,881    $178,445              2.46 cents
# 3        1820        9,633,822    $208,526              2.16 cents
# 4        1830       12,866,020    $378,545              2.94 cents

# %% [markdown]
# - 2. Find out how many rows and columns it has

# %%
len(df)
# Out:
# 23

# %%
len(df.columns)
# Out:
# 4

# %% [markdown]
# - 3. Display first 10, last 10, and random 10 rows

# %%
df.head(10)
# Out:
#   Census Year Total Population Census Cost Average Cost Per Person
# 0        1790        3,929,214     $44,377              1.13 cents
# 1        1800        5,308,483     $66,109              1.24 cents
# 2        1810        7,239,881    $178,445              2.46 cents
# 3        1820        9,633,822    $208,526              2.16 cents
# 4        1830       12,866,020    $378,545              2.94 cents
# 5        1840       17,069,458    $833,371              4.88 cents
# 6        1850       23,191,876  $1,423,351              6.14 cents
# 7        1860       31,443,321  $1,969,377              6.26 cents
# 8        1870       38,558,371  $3,421,198              8.87 cents
# 9        1880       50,155,783  $5,790,678             11.54 cents

# %%
df.tail(10)
# Out:
#    Census Year Total Population     Census Cost Average Cost Per Person
# 13        1920      105,710,620     $25,117,000             23.76 cents
# 14        1930      122,775,046     $40,156,000             32.71 cents
# 15        1940      131,669,275     $67,527,000             51.29 cents
# 16        1950      151,325,798     $91,462,000             60.44 cents
# 17        1960      179,323,175    $127,934,000             71.34 cents
# 18        1970      203,302,031    $247,653,000                   $1.22
# 19        1980      226,542,199  $1,078,488,000                   $4.76
# 20        1990      248,718,301  $2,492,830,000                  $10.02
# 21        2000      281,421,906    $4.5 Billion                  $15.99
# 22       2010*      308,745,538     $13 Billion                  $42.11

# %%
df.sample(10)
# Out:
#    Census Year Total Population  Census Cost Average Cost Per Person
# 2         1810        7,239,881     $178,445              2.46 cents
# 12        1910       91,972,266  $15,968,000             17.07 cents
# 16        1950      151,325,798  $91,462,000             60.44 cents
# 3         1820        9,633,822     $208,526              2.16 cents
# 8         1870       38,558,371   $3,421,198              8.87 cents
# 4         1830       12,866,020     $378,545              2.94 cents
# 6         1850       23,191,876   $1,423,351              6.14 cents
# 1         1800        5,308,483      $66,109              1.24 cents
# 10        1890       62,979,766  $11,547,127             18.33 cents
# 0         1790        3,929,214      $44,377              1.13 cents

# %% [markdown]
# - 4. Find out the data types of all columns - use info() function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Census Year              23 non-null     object
#  1   Total Population         23 non-null     object
#  2   Census Cost              23 non-null     object
#  3   Average Cost Per Person  23 non-null     object
# dtypes: object(4)
# memory usage: 864.0+ bytes

# %% [markdown]
# - 5. Find out the summary statistics of all columns

# %%
df.describe()
# Out:
#        Census Year Total Population  Census Cost Average Cost Per Person
# count           23               23           23                      23
# unique          23               23           23                      23
# top           1950      122,775,046  $25,117,000                   $4.76
# freq             1                1            1                       1

# %% [markdown]
# - 6. Cleanse the data to make the year, population, cost, cost per person numerical type - use apply() function

# %%
def cleanse_pop(a_string):
  return (a_string.replace(",","").replace("*","")).replace("cents","").replace("$","")
df["year_list"] = df["Census Year"].apply(cleanse_pop)  
df["tot_pop"] = df["Total Population"].apply(cleanse_pop)
df["avg_cost_pp"]=df["Average Cost Per Person"].apply(cleanse_pop)
df
# Out:
#    Census Year Total Population  ... census_year avg_cost_pp
# 0         1790        3,929,214  ...        1790       1.13
# 1         1800        5,308,483  ...        1800       1.24
# 2         1810        7,239,881  ...        1810       2.46
# 3         1820        9,633,822  ...        1820       2.16
# 4         1830       12,866,020  ...        1830       2.94
# 5         1840       17,069,458  ...        1840       4.88
# 6         1850       23,191,876  ...        1850       6.14
# 7         1860       31,443,321  ...        1860       6.26
# 8         1870       38,558,371  ...        1870       8.87
# 9         1880       50,155,783  ...        1880      11.54
# 10        1890       62,979,766  ...        1890      18.33
# 11        1900       76,303,387  ...        1900      15.54
# 12        1910       91,972,266  ...        1910      17.07
# 13        1920      105,710,620  ...        1920      23.76
# 14        1930      122,775,046  ...        1930      32.71
# 15        1940      131,669,275  ...        1940      51.29
# 16        1950      151,325,798  ...        1950      60.44
# 17        1960      179,323,175  ...        1960      71.34
# 18        1970      203,302,031  ...        1970        1.22
# 19        1980      226,542,199  ...        1980        4.76
# 20        1990      248,718,301  ...        1990       10.02
# 21        2000      281,421,906  ...        2000       15.99
# 22       2010*      308,745,538  ...        2010       42.11
#
# [23 rows x 8 columns]

# %% [markdown]
# - 7. Find out the summary statistics of the numerical columns - use describe() function

# %%
df.describe()
# Out:
#        census_year
# count      23.0000
# mean     1900.0000
# std        67.8233
# min      1790.0000
# 25%      1845.0000
# 50%      1900.0000
# 75%      1955.0000
# max      2010.0000

# %% [markdown]
# - 8.Use Pandas built-in plotting function to plot the average cost per person over time.

# %%
df
# Out:
#    Census Year Total Population  ... census_year avg_cost_pp
# 0         1790        3,929,214  ...        1790       1.13
# 1         1800        5,308,483  ...        1800       1.24
# 2         1810        7,239,881  ...        1810       2.46
# 3         1820        9,633,822  ...        1820       2.16
# 4         1830       12,866,020  ...        1830       2.94
# 5         1840       17,069,458  ...        1840       4.88
# 6         1850       23,191,876  ...        1850       6.14
# 7         1860       31,443,321  ...        1860       6.26
# 8         1870       38,558,371  ...        1870       8.87
# 9         1880       50,155,783  ...        1880      11.54
# 10        1890       62,979,766  ...        1890      18.33
# 11        1900       76,303,387  ...        1900      15.54
# 12        1910       91,972,266  ...        1910      17.07
# 13        1920      105,710,620  ...        1920      23.76
# 14        1930      122,775,046  ...        1930      32.71
# 15        1940      131,669,275  ...        1940      51.29
# 16        1950      151,325,798  ...        1950      60.44
# 17        1960      179,323,175  ...        1960      71.34
# 18        1970      203,302,031  ...        1970        1.22
# 19        1980      226,542,199  ...        1980        4.76
# 20        1990      248,718,301  ...        1990       10.02
# 21        2000      281,421,906  ...        2000       15.99
# 22       2010*      308,745,538  ...        2010       42.11
#
# [23 rows x 8 columns]

# %%
df.plot.line(x=0, y=7)

# %% [markdown]
# - 8. Use Pandas built-in plotting function to plot the scatter plot of Total Population vs Total Cost.

# %%
df.plot.scatter(5, 2)
