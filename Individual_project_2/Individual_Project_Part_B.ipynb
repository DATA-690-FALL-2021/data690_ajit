# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitjadhav10/data690_ajit/blob/main/Individual_project_2/Individual_Project_Part_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Topic: Does education have an effect on the participation of women in workforce?
#
# - Name: Ajit Jadhav

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

# %%
import plotly

print(plotly.__version__)
# Out:
# 5.3.1

# %%
pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %%
pio.templates.default = "plotly_dark"

# %%
# !pip install plotly --upgrade

# %%
df_1=pd.read_csv('https://raw.githubusercontent.com/ajitjadhav10/data690_ajit/main/individual_project_part_b/wdi_data.csv')
df_1.head(10)
# Out:
#    Unnamed: 0  Year  ...         Income Group Lending Type
# 0           0  2010  ...           Low income          IDA
# 1           1  2011  ...           Low income          IDA
# 2           2  2012  ...           Low income          IDA
# 3           3  2013  ...           Low income          IDA
# 4           4  2014  ...           Low income          IDA
# 5           5  2015  ...           Low income          IDA
# 6           6  2016  ...           Low income          IDA
# 7           7  2017  ...           Low income          IDA
# 8           8  2018  ...           Low income          IDA
# 9           9  2010  ...  Upper middle income         IBRD
#
# [10 rows x 9 columns]

# %%
df_1.drop(columns=["Unnamed: 0"], inplace=True)
df_1
# Out:
#        Year         value  ...         Income Group Lending Type
# 0      2010  2.918551e+07  ...           Low income          IDA
# 1      2011  3.011741e+07  ...           Low income          IDA
# 2      2012  3.116138e+07  ...           Low income          IDA
# 3      2013  3.226959e+07  ...           Low income          IDA
# 4      2014  3.337080e+07  ...           Low income          IDA
# ...     ...           ...  ...                  ...          ...
# 10058  2014  5.841000e+01  ...  Lower middle income        Blend
# 10059  2015  5.953400e+01  ...  Lower middle income        Blend
# 10060  2016  6.029400e+01  ...  Lower middle income        Blend
# 10061  2017  6.081200e+01  ...  Lower middle income        Blend
# 10062  2018  6.119500e+01  ...  Lower middle income        Blend
#
# [10063 rows x 8 columns]

# %%
df_countries = df_1[df_1["Country Code"].isin(['AFG','BTN','IND','LKA','NPL','BGD','PAK'])]
df_countries
# Out:
#       Year         value  ...         Income Group Lending Type
# 0     2010  2.918551e+07  ...           Low income          IDA
# 1     2011  3.011741e+07  ...           Low income          IDA
# 2     2012  3.116138e+07  ...           Low income          IDA
# 3     2013  3.226959e+07  ...           Low income          IDA
# 4     2014  3.337080e+07  ...           Low income          IDA
# ...    ...           ...  ...                  ...          ...
# 9761  2014  7.614700e+01  ...  Lower middle income         IBRD
# 9762  2015  7.631600e+01  ...  Lower middle income         IBRD
# 9763  2016  7.648200e+01  ...  Lower middle income         IBRD
# 9764  2017  7.664800e+01  ...  Lower middle income         IBRD
# 9765  2018  7.681200e+01  ...  Lower middle income         IBRD
#
# [374 rows x 8 columns]

# %%
df_female_se = df_countries.query("indicator == 'SE.SEC.ENRL.FE.ZS'")
df_female_se
# Out:
#       Year     value  ...         Income Group Lending Type
# 3692  2010  32.00865  ...           Low income          IDA
# 3693  2011  34.45594  ...           Low income          IDA
# 3694  2012  34.63026  ...           Low income          IDA
# 3695  2013  34.43871  ...           Low income          IDA
# 3696  2014  34.62152  ...           Low income          IDA
# 3697  2015  34.69429  ...           Low income          IDA
# 3698  2016  35.18667  ...           Low income          IDA
# 3699  2017  35.03392  ...           Low income          IDA
# 3700  2018  35.12363  ...           Low income          IDA
# 3778  2010  51.88096  ...  Lower middle income          IDA
# 3779  2011  52.52608  ...  Lower middle income          IDA
# 3780  2012  52.19005  ...  Lower middle income          IDA
# 3781  2013  50.90999  ...  Lower middle income          IDA
# 3782  2015  51.89476  ...  Lower middle income          IDA
# 3783  2016  51.36834  ...  Lower middle income          IDA
# ...

# %%
df_pivot = df_female_se.pivot(index =['Year','Country Code','Country Name','Region','Income Group'],columns = 'indicator', values ='value').reset_index()
df_pivot.reset_index().head()
# Out:
# indicator  index  Year  ...         Income Group SE.SEC.ENRL.FE.ZS
# 0              0  2010  ...           Low income          32.00865
# 1              1  2010  ...  Lower middle income          51.88096
# 2              2  2010  ...  Lower middle income          49.88007
# 3              3  2010  ...  Lower middle income          45.62132
# 4              4  2010  ...  Lower middle income          49.87002
#
# [5 rows x 7 columns]

# %%
fig = px.line(
    df_pivot, 
    x="Year", 
    y="SE.SEC.ENRL.FE.ZS",
    labels={"SE.SEC.ENRL.FE.ZS":"Secondary education, pupils (% female)"},
    hover_name='Country Name',
    color='Country Name'
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_female_lf = df_countries.query("indicator == 'SL.TLF.CACT.FE.ZS'")
df_female_lf
# Out:
#       Year  value  ...         Income Group Lending Type
# 6577  2010  15.13  ...           Low income          IDA
# 6578  2011  15.44  ...           Low income          IDA
# 6579  2012  15.85  ...           Low income          IDA
# 6580  2013  16.77  ...           Low income          IDA
# 6581  2014  17.74  ...           Low income          IDA
# ...    ...    ...  ...                  ...          ...
# 7967  2014  34.46  ...  Lower middle income         IBRD
# 7968  2015  35.74  ...  Lower middle income         IBRD
# 7969  2016  35.84  ...  Lower middle income         IBRD
# 7970  2017  36.60  ...  Lower middle income         IBRD
# 7971  2018  33.67  ...  Lower middle income         IBRD
#
# [63 rows x 8 columns]

# %%
df_pivot_1 = df_female_lf.pivot(index =['Year','Country Code','Country Name','Region','Income Group'],columns = 'indicator', values ='value').reset_index()
df_pivot_1.reset_index().head()
# Out:
# indicator  index  Year  ...         Income Group SL.TLF.CACT.FE.ZS
# 0              0  2010  ...           Low income             15.13
# 1              1  2010  ...  Lower middle income             29.85
# 2              2  2010  ...  Lower middle income             63.52
# 3              3  2010  ...  Lower middle income             25.85
# 4              4  2010  ...  Lower middle income             34.41
#
# [5 rows x 7 columns]

# %%
fig = px.line(
    df_pivot_1, 
    x="Year", 
    y="SL.TLF.CACT.FE.ZS",
    labels={"SL.TLF.CACT.FE.ZS":"Female Labor force participation rate(% of female population ages 15+)"},
    hover_name='Country Name',
    color='Country Name'
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_pivot_2 = df_countries.pivot(index =['Year','Country Code','Country Name','Region','Income Group'],columns = 'indicator', values ='value').reset_index()
df_pivot_2.reset_index().head()
# Out:
# indicator  index  Year  ... SP.DYN.LE00.IN   SP.POP.TOTL
# 0              0  2010  ...         61.028  2.918551e+07
# 1              1  2010  ...         69.881  1.475754e+08
# 2              2  2010  ...         68.384  6.855020e+05
# 3              3  2010  ...         66.693  1.234281e+09
# 4              4  2010  ...         75.439  2.026174e+07
#
# [5 rows x 12 columns]

# %%
df_pivot_2
fig = px.scatter(df_pivot_2, x="SL.TLF.CACT.FE.ZS", y="SE.SEC.ENRL.FE.ZS", color="Year", symbol="Year",size="Year")
fig.update_traces(marker_size=40)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_pivot_3 = df_pivot.query("Year == '2016'")

fig = px.bar(df_pivot_3, x='Country Name', y='SE.SEC.ENRL.FE.ZS',
             hover_data=['SE.SEC.ENRL.FE.ZS'], color='Country Name',
             labels={'pop':'population of Canada'}, height=700)
fig.show()


# fig = px.line(
#     df_pivot, 
#     x="Year", 
#     y="SE.SEC.ENRL.FE.ZS",
#     labels={"SE.SEC.ENRL.FE.ZS":"Secondary education, pupils (% female)"},
#     hover_name='Country Name',
#     color='Country Name'
#     )
# fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_pivot_4 = df_pivot_1.query("Year == '2016'")

fig_1 = px.bar(df_pivot_4, x='Country Name', y='SL.TLF.CACT.FE.ZS',
             hover_data=['SL.TLF.CACT.FE.ZS'], color='Country Name',
             labels={'pop':'population of Canada'}, height=700)
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
